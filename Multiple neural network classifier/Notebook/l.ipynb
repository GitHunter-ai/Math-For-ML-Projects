# %%
import sys
import os

# Add parent directory to Python path
sys.path.append(os.path.abspath("D:\Repositories\Math for ML\PR-Multiple neural network classifier"))
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\R'
# <>:5: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10728\2170016430.py:5: SyntaxWarning: invalid escape sequence '\R'
#   sys.path.append(os.path.abspath("D:\Repositories\Math for ML\PR-Multiple neural network classifier"))

# %% [markdown]
# ## Import libraries and predefined Modules

# %%
# 
from utils.plot import plot_data, plot_decision_boundary
from model.nn import NeuralNetwork as nn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
np.random.seed(2)

# %% [markdown]
# ## Load saved dataset (moons.csv)

# %%
data=pd.read_csv(r"D:\Repositories\Math for ML\PR-Multiple neural network classifier\Data\moons.csv")
info=data.head(),data.info()
print(info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      1000 non-null   float64
#  1   x2      1000 non-null   float64
#  2   label   1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB
# (         x1        x2  label
# 0 -0.111667  0.520224      1
# 1  1.142650 -0.342577      1
# 2  0.795558 -0.011442      1
# 3  0.111827 -0.551932      1
# 4 -0.816466  0.543996      0, None)

# %% [markdown]
# ## Reshaping data

# %%
X=data[["x1","x2"]].to_numpy().reshape(-1,2)
Y=data.label.to_numpy().reshape(-1,1)

# %% [markdown]
# ## Plot dataset

# %%
# X: (1000, 2), Y: (1000, 1)

plot_data(X, Y)

# %% [markdown]
# ## Train Model and plot boundary

# %%
# 1. Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=72)

# 2. Initialize and train the model
model = nn(n_h=10, learning_rate=1.8, num_iterations=5000)
model.fit(X_train, Y_train, print_cost=True)

# 3. Evaluate the model
acc = model.score(X_test, Y_test)
print(f"Test Accuracy: {acc:.2%} \n ")

# plot output
plot_decision_boundary(model.predict, X, Y)
# Out:
# cost after 0 iteration:0.6930934340738938
# cost after 50 iteration:0.2899870913682932
# cost after 100 iteration:0.2887391275778855
# cost after 150 iteration:0.2881353279809284
# cost after 200 iteration:0.28777356593032655
# cost after 250 iteration:0.28752997351718573
# cost after 300 iteration:0.28735304151546726
# cost after 350 iteration:0.2872170899658829
# cost after 400 iteration:0.28710802166802935
# cost after 450 iteration:0.2870176090116781
# cost after 500 iteration:0.28694077714557276
# cost after 550 iteration:0.2868742106752959
# cost after 600 iteration:0.2868156160785411
# cost after 650 iteration:0.286763320047742
# cost after 700 iteration:0.28671604096336684
# cost after 750 iteration:0.28667274998632025
# cost after 800 iteration:0.28663257859671043
# cost after 850 iteration:0.2865947492849726
# cost after 900 iteration:0.2865585152784249
# cost after 950 iteration:0.28652309858445874
# cost after 1000 iteration:0.2864876155099531
# ...

# %% [markdown]
# ## Second Dataset (circles.csv)

# %%
data1=pd.read_csv(r"D:\Repositories\Math for ML\PR-Multiple neural network classifier\Data\circles.csv")

X1=data1[["x1","x2"]].to_numpy().reshape(-1,2)
Y1=data1.label.to_numpy().reshape(-1,1)
plot_data(X1, Y1)

# %%
# # Train again
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(X1, Y1, test_size=0.2, random_state=42)
model1 = nn(n_h=10, learning_rate=1.2, num_iterations=5000)
model1.fit(X_train1, Y_train1, print_cost=True)
print(f"Test Accuracy: {model.score(X_test1, Y_test1):.2%}")
plot_decision_boundary(model1.predict, X1, Y1)
# Out:
# cost after 0 iteration:0.693134341174916
# cost after 50 iteration:0.6924012628253606
# cost after 100 iteration:0.6906786978461471
# cost after 150 iteration:0.6589138961531731
# cost after 200 iteration:0.48271924689942775
# cost after 250 iteration:0.3283486621276055
# cost after 300 iteration:0.23207368655263488
# cost after 350 iteration:0.21132166923901383
# cost after 400 iteration:0.2029419500101376
# cost after 450 iteration:0.19764191979929688
# cost after 500 iteration:0.19350058754735233
# cost after 550 iteration:0.1900208016221683
# cost after 600 iteration:0.18707955621023215
# cost after 650 iteration:0.18460458843021482
# cost after 700 iteration:0.1824869070510323
# cost after 750 iteration:0.18062051316483826
# cost after 800 iteration:0.17893282047652115
# cost after 850 iteration:0.1773832544753576
# cost after 900 iteration:0.175952977153446
# cost after 950 iteration:0.17463479576349317
# cost after 1000 iteration:0.17342543549165562
# ...

# %% [markdown]
# ## Final Dataset (Breast cancer)

# %%
data2=pd.read_csv(r"D:\Repositories\Math for ML\PR-Multiple neural network classifier\Data\breast_cancer.csv")

X2=data2[["x1","x2"]].to_numpy().reshape(-1,2)
Y2=data2.label.to_numpy().reshape(-1,1)
plot_data(X2, Y2)

# %%
# Train/test split
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(X2, Y2, test_size=0.2, random_state=7)
model2 = nn(n_h=10, learning_rate=1.2, num_iterations=5000)
model2.fit(X_train2, Y_train2, print_cost=True)
print(f"Test Acc2uracy: {model2.score(X_test2, Y_test2):.2%}")
plot_decision_boundary(model2.predict, X2, Y2)
# Out:
# cost after 0 iteration:0.6933104835049951
# cost after 50 iteration:0.2845850352417014
# cost after 100 iteration:0.2803684591468015
# cost after 150 iteration:0.2759798591775404
# cost after 200 iteration:0.271065506730454
# cost after 250 iteration:0.26560673663697226
# cost after 300 iteration:0.25990004737897376
# cost after 350 iteration:0.2544556946473538
# cost after 400 iteration:0.24976177021474624
# cost after 450 iteration:0.24608083794631194
# cost after 500 iteration:0.2434144501677314
# cost after 550 iteration:0.2415974307307146
# cost after 600 iteration:0.24041195896485684
# cost after 650 iteration:0.2735945723995233
# cost after 700 iteration:0.24974765890237033
# cost after 750 iteration:0.24669214770421796
# cost after 800 iteration:0.24560673063917818
# cost after 850 iteration:0.2446485726447699
# cost after 900 iteration:0.24379931162149726
# cost after 950 iteration:0.24304812323939815
# cost after 1000 iteration:0.24238067976799166
# ...
